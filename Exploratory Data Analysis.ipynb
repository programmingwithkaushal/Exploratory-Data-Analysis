# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv('/content/Zomato.csv', encoding='latin-1', on_bad_lines='skip')

# %%
data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                      0\t1\t2\t3\t4\t5\t6\t7\t8\t9\t10\t11\t12\t13\t14\t15\t16\t17\t18\t19\t20
# 18763512\tBarBerry\t1\tPune\t121/122        Rambaug Colony         Next lane of MIT COLLEGE                      Opposite Kheliya Shop                              Paud road                                   Kothrud                Pune\tKothrud\tKothrud                             Pune\t0.0000000000\t0.0000000000\tNorth Indian     Italian   Finger Food\t1200\tRs.\t0\t0\t0\t0\t3\t4.7\t3...
# ...

# %%
data.columns
# Out:
# Index(['0\t1\t2\t3\t4\t5\t6\t7\t8\t9\t10\t11\t12\t13\t14\t15\t16\t17\t18\t19\t20'], dtype='object')

# %%
data.shape
# Out:
# (871, 1)

# %%
q
